# %% [markdown]
# tetrad-magic triangle

# %%
import itertools

# %%
i=0
for A in itertools.permutations(range(9), 9):
    m=A[0]+A[1]+A[2]+A[3]
    n=A[1]+A[4]+A[5]+A[6]
    o=A[3]+A[6]+A[7]+A[8]
    if m==n and n == o:
        print(A,m)
        i+=1
print(i)
# Out:
# (0, 1, 8, 6, 5, 7, 2, 3, 4) 15
# (0, 1, 8, 6, 5, 7, 2, 4, 3) 15
# (0, 1, 8, 6, 7, 5, 2, 3, 4) 15
# (0, 1, 8, 6, 7, 5, 2, 4, 3) 15
# (0, 1, 8, 7, 5, 6, 4, 2, 3) 16
# (0, 1, 8, 7, 5, 6, 4, 3, 2) 16
# (0, 1, 8, 7, 6, 5, 4, 2, 3) 16
# (0, 1, 8, 7, 6, 5, 4, 3, 2) 16
# (0, 2, 7, 6, 4, 8, 1, 3, 5) 15
# (0, 2, 7, 6, 4, 8, 1, 5, 3) 15
# (0, 2, 7, 6, 8, 4, 1, 3, 5) 15
# (0, 2, 7, 6, 8, 4, 1, 5, 3) 15
# (0, 2, 7, 8, 4, 6, 5, 1, 3) 17
# (0, 2, 7, 8, 4, 6, 5, 3, 1) 17
# (0, 2, 7, 8, 6, 4, 5, 1, 3) 17
# (0, 2, 7, 8, 6, 4, 5, 3, 1) 17
# (0, 2, 8, 6, 3, 7, 4, 1, 5) 16
# (0, 2, 8, 6, 3, 7, 4, 5, 1) 16
# (0, 2, 8, 6, 7, 3, 4, 1, 5) 16
# (0, 2, 8, 6, 7, 3, 4, 5, 1) 16
# (0, 2, 8, 7, 4, 5, 6, 1, 3) 17
# (0, 2, 8, 7, 4, 5, 6, 3, 1) 17
# (0, 2, 8, 7, 5, 4, 6, 1, 3) 17
# (0, 2, 8, 7, 5, 4, 6, 3, 1) 17
# (0, 3, 8, 5, 2, 7, 4, 1, 6) 16
# (0, 3, 8, 5, 2, 7, 4, 6, 1) 16
# (0, 3, 8, 5, 7, 2, 4, 1, 6) 16
# (0, 3, 8, 5, 7, 2, 4, 6, 1) 16
# (0, 4, 5, 7, 3, 8, 1, 2, 6) 16
# (0, 4, 5, 7, 3, 8, 1, 6, 2) 16
# ...

# %%
i=0
for A in itertools.permutations(range(16), 16):
    if A[0]+A[1]+A[2]+A[3]==30:
        if A[4]+A[9]+A[10]+A[11]==30:
            if A[8]+A[13]+A[14]+A[15]==30:
                if A[1]+A[4]+A[5]+A[6]==30:
                    if A[3]+A[6]+A[7]+A[8]==30:
                        if A[6]+A[11]+A[12]+A[13]==30:
                            print(A,m)
                            i+=1
print(i)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-0566665dbcb7> in <module>
#       1 i=0
#       2 for A in itertools.permutations(range(16), 16):
# ----> 3     if A[0]+A[1]+A[2]+A[3]==30:
#       4         if A[4]+A[9]+A[10]+A[11]==30:
#       5             if A[8]+A[13]+A[14]+A[15]==30:
#
# KeyboardInterrupt:

# %%
i=0
for A in itertools.permutations(range(16), 4):
    if A[0]+A[1]+A[2]+A[3]==30:
        print(A,30)
        i+=1
print(i)
# Out:
# (0, 1, 14, 15) 30
# (0, 1, 15, 14) 30
# (0, 2, 13, 15) 30
# (0, 2, 15, 13) 30
# (0, 3, 12, 15) 30
# (0, 3, 13, 14) 30
# (0, 3, 14, 13) 30
# (0, 3, 15, 12) 30
# (0, 4, 11, 15) 30
# (0, 4, 12, 14) 30
# (0, 4, 14, 12) 30
# (0, 4, 15, 11) 30
# (0, 5, 10, 15) 30
# (0, 5, 11, 14) 30
# (0, 5, 12, 13) 30
# (0, 5, 13, 12) 30
# (0, 5, 14, 11) 30
# (0, 5, 15, 10) 30
# (0, 6, 9, 15) 30
# (0, 6, 10, 14) 30
# (0, 6, 11, 13) 30
# (0, 6, 13, 11) 30
# (0, 6, 14, 10) 30
# (0, 6, 15, 9) 30
# (0, 7, 8, 15) 30
# (0, 7, 9, 14) 30
# (0, 7, 10, 13) 30
# (0, 7, 11, 12) 30
# (0, 7, 12, 11) 30
# (0, 7, 13, 10) 30
# (0, 7, 14, 9) 30
# (0, 7, 15, 8) 30
# (0, 8, 7, 15) 30
# (0, 8, 9, 13) 30
# (0, 8, 10, 12) 30
# (0, 8, 12, 10) 30
# (0, 8, 13, 9) 30
# (0, 8, 15, 7) 30
# (0, 9, 6, 15) 30
# (0, 9, 7, 14) 30
# (0, 9, 8, 13) 30
# (0, 9, 10, 11) 30
# (0, 9, 11, 10) 30
# (0, 9, 13, 8) 30
# (0, 9, 14, 7) 30
# (0, 9, 15, 6) 30
# (0, 10, 5, 15) 30
# (0, 10, 6, 14) 30
# (0, 10, 7, 13) 30
# (0, 10, 8, 12) 30
# ...

# %%
pow(4128,4)
# Out:
# 290374686867456

# %%
i=0
for A in itertools.combinations(range(16), 4):
    if A[0]+A[1]+A[2]+A[3]==30:
        print(A,30)
        i+=1
print(i)
# Out:
# (0, 1, 14, 15) 30
# (0, 2, 13, 15) 30
# (0, 3, 12, 15) 30
# (0, 3, 13, 14) 30
# (0, 4, 11, 15) 30
# (0, 4, 12, 14) 30
# (0, 5, 10, 15) 30
# (0, 5, 11, 14) 30
# (0, 5, 12, 13) 30
# (0, 6, 9, 15) 30
# (0, 6, 10, 14) 30
# (0, 6, 11, 13) 30
# (0, 7, 8, 15) 30
# (0, 7, 9, 14) 30
# (0, 7, 10, 13) 30
# (0, 7, 11, 12) 30
# (0, 8, 9, 13) 30
# (0, 8, 10, 12) 30
# (0, 9, 10, 11) 30
# (1, 2, 12, 15) 30
# (1, 2, 13, 14) 30
# (1, 3, 11, 15) 30
# (1, 3, 12, 14) 30
# (1, 4, 10, 15) 30
# (1, 4, 11, 14) 30
# (1, 4, 12, 13) 30
# (1, 5, 9, 15) 30
# (1, 5, 10, 14) 30
# (1, 5, 11, 13) 30
# (1, 6, 8, 15) 30
# (1, 6, 9, 14) 30
# (1, 6, 10, 13) 30
# (1, 6, 11, 12) 30
# (1, 7, 8, 14) 30
# (1, 7, 9, 13) 30
# (1, 7, 10, 12) 30
# (1, 8, 9, 12) 30
# (1, 8, 10, 11) 30
# (2, 3, 10, 15) 30
# (2, 3, 11, 14) 30
# (2, 3, 12, 13) 30
# (2, 4, 9, 15) 30
# (2, 4, 10, 14) 30
# (2, 4, 11, 13) 30
# (2, 5, 8, 15) 30
# (2, 5, 9, 14) 30
# (2, 5, 10, 13) 30
# (2, 5, 11, 12) 30
# (2, 6, 7, 15) 30
# (2, 6, 8, 14) 30
# ...

# %%
pow(86,4)
# Out:
# 54700816

# %%
import numpy as np
XX=np.zeros([86,4],dtype=int)

# %%
XX=np.zeros([86,4],dtype=int)
i=0
for A in itertools.combinations(range(16), 4):
    if A[0]+A[1]+A[2]+A[3]==30:
        XX[i]=A
        i+=1
print(i)
# Out:
# 86

# %%
k=0
for i in range(86):
    for j in range(86):
        if len(set(list(XX[i])+list(XX[j])))==8:
            print(i,j)
            k+=1
print(k)
# Out:
# 0 40
# 0 43
# 0 46
# 0 47
# 0 50
# 0 51
# 0 52
# 0 53
# 0 54
# 0 55
# 0 58
# 0 59
# 0 62
# 0 63
# 0 65
# 0 66
# 0 67
# 0 68
# 0 69
# 0 70
# 0 73
# 0 74
# 0 75
# 0 76
# 0 77
# 0 78
# 0 79
# 0 80
# 0 81
# 0 82
# 0 83
# 0 84
# 0 85
# 1 22
# 1 24
# 1 27
# 1 30
# 1 32
# 1 33
# 1 35
# 1 36
# 1 37
# 1 57
# 1 59
# 1 61
# 1 63
# 1 64
# 1 66
# 1 67
# 1 68
# 1 69
# 1 70
# 1 72
# 1 74
# 1 75
# 1 77
# 1 78
# 1 79
# 1 80
# 1 81
# 1 82
# 1 83
# 1 84
# 1 85
# 2 20
# 2 24
# 2 27
# 2 28
# 2 30
# 2 31
# 2 33
# 2 34
# 2 37
# 2 42
# 2 43
# 2 45
# 2 46
# 2 49
# 2 50
# 2 52
# 2 54
# 2 55
# 2 72
# 2 73
# 2 75
# 2 76
# 2 78
# 2 79
# 2 80
# 2 82
# 2 83
# 2 84
# 2 85
# 3 19
# 3 23
# 3 26
# 3 29
# 3 32
# 3 35
# 3 36
# 3 37
# 3 41
# 3 44
# 3 47
# 3 48
# 3 51
# 3 53
# 3 54
# 3 55
# 3 71
# 3 74
# 3 75
# 3 77
# 3 78
# 3 79
# 3 80
# 3 81
# 3 82
# 3 83
# 3 84
# 3 85
# 4 20
# 4 22
# 4 27
# 4 30
# 4 31
# 4 33
# 4 34
# 4 35
# 4 36
# 4 40
# 4 45
# 4 46
# 4 49
# 4 50
# 4 51
# 4 52
# 4 53
# 4 61
# 4 62
# 4 63
# 4 64
# ...

# %%
AAA8=np.zeros([2150,8],dtype=int)
AAA2=np.zeros([2150,2],dtype=int)
k=0
for i in range(86):
    for j in range(86):
        if len(set(list(XX[i])+list(XX[j])))==8:
            AAA2[k,:]=np.array([i,j],dtype=int)
            AAA8[k,0:4]=XX[i]
            AAA8[k,4:8]=XX[j]
            k+=1
print(k)
# Out:
# 2150

# %%
XX[j]
# Out:
# array([ 2,  3, 12, 13])

# %%
AAA8
# Out:
# array([[ 0,  1, 14, ...,  3, 12, 13],
#        [ 0,  1, 14, ...,  4, 11, 13],
#        [ 0,  1, 14, ...,  5, 10, 13],
#        ...,
#        [ 6,  7,  8, ...,  4, 11, 12],
#        [ 6,  7,  8, ...,  5, 10, 12],
#        [ 6,  7,  8, ...,  5, 10, 11]])

# %%
k=0
for i in range(2150):
    for j in range(2150):
        if len(set(list(AAA8[i])+list(AAA8[j])))==16:
            k+=1
print(k)
# Out:
# 9408

# %%
AAA2
# Out:
# array([[ 0, 40],
#        [ 0, 43],
#        [ 0, 46],
#        ...,
#        [85, 59],
#        [85, 63],
#        [85, 75]])

# %%
9408*pow(24,3)*4
# Out:
# 520224768

# %%
9408*pow(12,3)*4
# Out:
# 65028096

# %%
k=0
AAAA=np.zeros([9408,16],dtype=int)
AAAA4=np.zeros([9408,4],dtype=int)
for i in range(2150):
    for j in range(2150):
        if len(set(list(AAA8[i])+list(AAA8[j])))==16:
            AAAA4[k,0:2]=AAA2[i]
            AAAA4[k,2:4]=AAA2[j]
            AAAA[k,0:8]=AAA8[i]
            AAAA[k,8:16]=AAA8[j]
            k+=1
print(k)
# Out:
# 9408

# %%
for i in len(AAAA):
    for j in itertools.permutations(range(4), 2):
        for k in itertools.permutations(range(4), 2):
            for l in itertools.permutations(range(4), 2):
                for m in itertools.permutations(range(4), 1):
# Out:
# array([[ 0,  1, 14, ...,  7,  8,  9],
#        [ 0,  1, 14, ...,  7,  8, 10],
#        [ 0,  1, 14, ...,  6,  9, 10],
#        ...,
#        [ 6,  7,  8, ...,  3, 12, 15],
#        [ 6,  7,  8, ...,  2, 13, 15],
#        [ 6,  7,  8, ...,  1, 14, 15]])

# %%
permute1=np.zeros([24,4],dtype=int)
i=0
for j in itertools.permutations(range(4), 4):
    permute1[i,:]=j
    i+=1

# %%
permute0=permute1[range(0,24,2)]

# %%
permute0
# Out:
# array([[0, 1, 2, 3],
#        [0, 2, 1, 3],
#        [0, 3, 1, 2],
#        [1, 0, 2, 3],
#        [1, 2, 0, 3],
#        [1, 3, 0, 2],
#        [2, 0, 1, 3],
#        [2, 1, 0, 3],
#        [2, 3, 0, 1],
#        [3, 0, 1, 2],
#        [3, 1, 0, 2],
#        [3, 2, 0, 1]])

# %%
permute4=permute1[range(0,24,6)]

# %%
permute4
# Out:
# array([[0, 1, 2, 3],
#        [1, 0, 2, 3],
#        [2, 0, 1, 3],
#        [3, 0, 1, 2]])

# %%
lens=0
for i in range(len(AAAA)):
    for j in range(4):
        temp0=AAAA[i,0:4][permute4[j]]
        for k in range(12):
            temp1=AAAA[i,4:8][permute0[k]]
            for l in range(12):
                temp2=AAAA[i,8:12][permute0[l]]
                for m in range(12):
                    temp3=AAAA[i,12:16][permute0[m]]
                    x=temp0[0]+temp0[2]+temp1[0]+temp3[1]
                    y=temp0[0]+temp0[3]+temp2[0]+temp1[1]
                    z=temp0[0]+temp0[1]+temp3[0]+temp2[1]
                    if x == 30 and y == 30 and z == 30:
                        print(temp0,temp1,temp2,temp3)
                        lens+=1
print(lens)
# Out:
# [15  0  3 12] [ 5  1 10 14] [ 2  9  8 11] [ 6  7  4 13]
# [15  0  3 12] [ 5  1 10 14] [ 2 11  8  9] [ 4  7  6 13]
# [12  0  3 15] [ 5  1 11 13] [ 2 14  6  8] [ 4 10  7  9]
# [12  0  3 15] [11  1  5 13] [ 2  8  6 14] [10  4  7  9]
# [15  0  3 12] [ 5  1 11 13] [ 2  6  8 14] [ 9  7  4 10]
# [12  0  3 15] [10  1  6 13] [ 2 11  8  9] [ 7  5  4 14]
# [12  0  3 15] [ 9  1  7 13] [ 2 10  4 14] [ 8  6  5 11]
# [15  0  3 12] [ 7  1  9 13] [ 2  4 10 14] [11  5  6  8]
# [ 0  3 12 15] [11 10  1  8] [ 5 14  2  9] [13  7  4  6]
# [ 3  0 12 15] [ 8 10  1 11] [ 2 14  5  9] [13  7  4  6]
# [ 3  0 12 15] [11 10  1  8] [ 2 14  5  9] [13  4  6  7]
# [12  0  3 15] [ 8  1 10 11] [ 2  5  9 14] [13  7  4  6]
# [12  0  3 15] [ 8  1 10 11] [ 2 14  5  9] [ 4  7  6 13]
# [12  0  3 15] [11  1  8 10] [ 2  5  9 14] [13  4  6  7]
# [15  0  3 12] [ 8  1 10 11] [ 2  9  5 14] [ 6  4  7 13]
# [ 3  0 12 15] [ 8 10  1 11] [ 2 13  6  9] [14  7  4  5]
# [ 3  0 12 15] [11 10  1  8] [ 2 13  6  9] [14  4  5  7]
# ...

# %%
lens
# Out:
# 1435

# %%
lens=0
for i in range(len(AAAA)):
    for j in range(4):
        temp0=AAAA[i,0:4][permute4[j]]
        for k in range(12):
            temp1=AAAA[i,4:8][permute0[k]]
            for l in range(12):
                temp2=AAAA[i,8:12][permute0[l]]
                for m in range(12):
                    temp3=AAAA[i,12:16][permute0[m]]
                    x=temp0[0]+temp0[2]+temp1[0]+temp3[1]
                    y=temp0[0]+temp0[3]+temp2[0]+temp1[1]
                    z=temp0[0]+temp0[1]+temp3[0]+temp2[1]
                    if x == 30 and y == 30 and z == 30:
                        print(temp0,temp1,temp2,temp3)
                        lens+=1
print(lens)
# Out:
# [15  0  3 12] [ 5  1 10 14] [ 2  9  8 11] [ 6  7  4 13]
# [15  0  3 12] [ 5  1 10 14] [ 2 11  8  9] [ 4  7  6 13]
# [12  0  3 15] [ 5  1 11 13] [ 2 14  6  8] [ 4 10  7  9]
# [12  0  3 15] [11  1  5 13] [ 2  8  6 14] [10  4  7  9]
# [15  0  3 12] [ 5  1 11 13] [ 2  6  8 14] [ 9  7  4 10]
# [12  0  3 15] [10  1  6 13] [ 2 11  8  9] [ 7  5  4 14]
# [12  0  3 15] [ 9  1  7 13] [ 2 10  4 14] [ 8  6  5 11]
# [15  0  3 12] [ 7  1  9 13] [ 2  4 10 14] [11  5  6  8]
# [ 0  3 12 15] [11 10  1  8] [ 5 14  2  9] [13  7  4  6]
# [ 3  0 12 15] [ 8 10  1 11] [ 2 14  5  9] [13  7  4  6]
# [ 3  0 12 15] [11 10  1  8] [ 2 14  5  9] [13  4  6  7]
# [12  0  3 15] [ 8  1 10 11] [ 2  5  9 14] [13  7  4  6]
# [12  0  3 15] [ 8  1 10 11] [ 2 14  5  9] [ 4  7  6 13]
# [12  0  3 15] [11  1  8 10] [ 2  5  9 14] [13  4  6  7]
# [15  0  3 12] [ 8  1 10 11] [ 2  9  5 14] [ 6  4  7 13]
# [ 3  0 12 15] [ 8 10  1 11] [ 2 13  6  9] [14  7  4  5]
# [ 3  0 12 15] [11 10  1  8] [ 2 13  6  9] [14  4  5  7]
# ...

# %%
AAAA[i,0:4][permute4[j]]
# Out:
# array([ 0,  1, 14, 15])

# %%
j=0
